# %%
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import pandas as pd
import pprint as pprint 
import os

# %%
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
dirName = 'Resources/Tables'
listoffiles= getListOfFiles(dirName)
listoffiles
# Out:
# ['Resources/Tables\\23173_table.csv',
#  'Resources/Tables\\23219_table.csv',
#  'Resources/Tables\\23220_table.csv',
#  'Resources/Tables\\23221_table.csv',
#  'Resources/Tables\\23222_table.csv',
#  'Resources/Tables\\23223_table.csv',
#  'Resources/Tables\\23224_table.csv',
#  'Resources/Tables\\23225_table.csv',
#  'Resources/Tables\\23226_table.csv',
#  'Resources/Tables\\23227_table.csv',
#  'Resources/Tables\\23228_table.csv',
#  'Resources/Tables\\23229_table.csv',
#  'Resources/Tables\\23230_table.csv',
#  'Resources/Tables\\23231_table.csv',
#  'Resources/Tables\\23233_table.csv',
#  'Resources/Tables\\23234_table.csv',
#  'Resources/Tables\\23235_table.csv',
#  'Resources/Tables\\23236_table.csv',
#  'Resources/Tables\\23238_table.csv',
#  'Resources/Tables\\23294_table.csv']

# %%
Richmond_zipcodes = ['23173', '23219', '23220', '23221', '23222', '23223', \
                     '23224', '23225', '23226', '23227', '23228', '23229', '23230', '23231', '23233','23234', '23235', \
                    '23236', '23238', '23294']
table_dfs =[]
for zipcode in Richmond_zipcodes:
    df_name = zipcode
    table_dfs.append(df_name)
    
table_dfs
# Out:
# ['23173',
#  '23219',
#  '23220',
#  '23221',
#  '23222',
#  '23223',
#  '23224',
#  '23225',
#  '23226',
#  '23227',
#  '23228',
#  '23229',
#  '23230',
#  '23231',
#  '23233',
#  '23234',
#  '23235',
#  '23236',
#  '23238',
#  '23294']

# %%
list_of_dfs = []
for df, file in zip(table_dfs, listoffiles):
    df = pd.read_csv(file)
    list_of_dfs.append(df)
list_of_dfs[2].head()
# Out:
#                 Subject  Unnamed: 1 ZCTA5 23220  Unnamed: 3  Unnamed: 4  \
# 0                   NaN         NaN    Estimate         NaN         NaN
# 1           SEX AND AGE         NaN         NaN         NaN         NaN
# 2      Total population         NaN      34,409         NaN         NaN
# 3                  Male         NaN      16,717         NaN         NaN
# 4                Female         NaN      17,692         NaN         NaN
#
#         Unnamed: 5 Unnamed: 6               Unnamed: 7  Unnamed: 8
# 0  Margin of Error    Percent  Percent Margin of Error         NaN
# 1              NaN        NaN                      NaN         NaN
# 2         +/-1,284     34,409                      (X)         NaN
# 3           +/-817      48.6%                   +/-1.5         NaN
# 4           +/-818      51.4%                   +/-1.5         NaN

# %%
clean_dfs = []
count = 0
for df in list_of_dfs:
    drop_col = df.drop(['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 4'], axis=1)
    if 'Unnamed: 8' in drop_col:
        print(f'found col 8 in df')
        drop_col = drop_col.drop(columns=['Unnamed: 8'])
    df_rename_col = drop_col.rename(columns={"Subject": "Subject", (f"ZCTA5 {Richmond_zipcodes[count]}"): "Estimate", 'Unnamed: 5': 'Margin of Error', \
                                             'Unnamed: 6': 'Percent', 'Unnamed: 7': 'Percent Margin of Error'})
    df_dropna = df_rename_col.dropna(how='any')
    count = count + 1
    clean_dfs.append(df_dropna)
# Out:
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df
# found col 8 in df

# %%
df_rename_col.head()
# Out:
#                 Subject  Estimate  Margin of Error  Percent  \
# 0                   NaN  Estimate  Margin of Error  Percent
# 1           SEX AND AGE       NaN              NaN      NaN
# 2      Total population    17,848           +/-790   17,848
# 3                  Male     8,480           +/-531    47.5%
# 4                Female     9,368           +/-511    52.5%
#
#    Percent Margin of Error
# 0  Percent Margin of Error
# 1                      NaN
# 2                      (X)
# 3                   +/-1.9
# 4                   +/-1.9

# %%
clean_dfs[0].head()
# Out:
#                                    Subject Estimate Margin of Error Percent  \
# 1                         Total population    2,209          +/-288   2,209
# 2                                     Male      953          +/-215  43.10%
# 3                                   Female    1,256          +/-200  56.90%
# 4        Sex ratio (males per 100 females)     75.9         +/-21.6     (X)
# 6                            Under 5 years        0           +/-12   0.00%
#
#   Percent Margin of Error
# 1                     (X)
# 2                  +/-6.9
# 3                  +/-6.9
# 4                     (X)
# 6                  +/-1.5

# %%
clean_dfs[0].to_html('test.html')

# %%
df_rename_col.to_html('test1.html')

# %%
#Beginning Scrapping

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
apartments_url = 'https://www.apartments.com/richmond-va/'
browser.visit(apartments_url)

# %%
apartments_html = browser.html
apartments_soup = bs(apartments_html, 'html.parser')

# %%
print(apartments_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="js webgl geolocation cssanimations csstransforms csstransforms3d csstransitions svg" data-placeholder-focus="true" id="appContainer" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <style type="text/css">
#    .gm-control-active&gt;img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active&gt;img:nth-child(1){display:block}.gm-control-active:hover&gt;img:nth-child(1),.gm-control-active:active&gt;img:nth-child(1){display:none}.gm-control-active:hover&gt;img:nth-child(2),.gm-control-active:active&gt;img:nth-child(3){display:block}
#   </style>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    .gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
#   </style>
#   <style type="text/css">
#    .gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
#   </style>
#   <style type="text/css">
#    @media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}
#   </style>
#   <style type="text/css">
#    .gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}
#   </style>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="email=no" name="format-detection"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <title>
#    Apartments for Rent in Richmond VA | Apartments.com
#   </title>
#   <link href="/a/8a55f9/favicon.ico" rel="icon"/>
#   <link href="https://www.apartments.com/richmond-va/" rel="canonical"/>
#   <link href="https://plus.google.com/+apartmentscom/" rel="publisher"/>
#   <meta content="See all 3,427 apartments in Richmond, VA currently available for rent. Each Apartments.com listing has verified availability, rental rates, photos, floor plans and more." name="description"/>
#   <meta content="en" name="language"/>
#   <meta content="en" http-equiv="language"/>
#   <meta content="en-US" http-equiv="content-language"/>
#   <meta content="739299276152207" property="fb:app_id"/>
#   <meta content="Apartments.com" property="og:site_name"/>
#   <meta content="https://www.apartments.com/richmond-va/" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content=" Apartments for Rent in Richmond VA | Apartments.com" property="og:title"/>
#   <meta content="https://images1.apartments.com/i2/gJEDmm31mf6bhGriLioi0tqm1-71m02ARlmXDwziRLw/117/image.jpg" property="og:image"/>
#   <meta content="7/26/2019 8:15:57 PM" property="og:updated_time"/>
#   <meta content="We simplify the process of finding a new apartment by offering renters the most comprehensive database including millions of detailed and accurate apartment listings across the United States. Our innovative technology includes the POLYGON™ search tool that allows users to define their own search areas on a map and a Plan Commute feature that helps users search for rentals in proximity to their office." property="og:description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@apartmentscom" name="twitter:creator"/>
#   <meta content=" Apartments for Rent in Richmond VA | Apartments.com" name="twitter:title"/>
#   <meta content="https://images1.apartments.com/i2/gJEDmm31mf6bhGriLioi0tqm1-71m02ARlmXDwziRLw/117/image.jpg" name="twitter:image"/>
#   <meta content="origin" name="referrer"/>
#   <link href="https://www.apartments.com/richmond-va/" hreflang="en-US" rel="alternate"/>
#   <link href="https://www.apartments.com/richmond-va/" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.apartments.com/es/richmond-va/" hreflang="es-US" rel="alternate"/>
#   <link href="https://www.apartments.com/richmond-va/2/" rel="next"/>
#   <link as="font" crossorigin="" href="/a/86be74/content/fonts/apartmenticons.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="/a/48178f/content/fonts/lineto-costar-brown-regular.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="/a/0b286e/content/fonts/lineto-costar-brown-light.woff" rel="preload"/>
#   <link as="font" crossorigin="" href="/a/d21ed8/content/fonts/lineto-costar-brown-bold.woff" rel="preload"/>
#   <link href="/content/style.bundle.css?v=aQ0UxQ6mpuLqN_SRRbN3gXhC9tHNgUucSU9a8aCm0ic" rel="stylesheet" type="text/css"/>
#   <link href="/Modules/Search/Content/style.bundle.css?v=G4VVZmPsR2uiNoqttoyl7qnYku073be4Q9yhOeTWyb8" rel="stylesheet" type="text/css"/>
#   <script src="https://cdn.krxd.net/userdata/get?pub=7b047035-d53d-4cbd-be67-f17f8b327f81&amp;kxfp=d207fab23b78219a5aa7aabac84b79aa019ffd6b&amp;technographics=1&amp;callback=Krux.ns.costargroupincparent.kxjsonp_userdata" type="text/javascript">
#   </script>
#   <script src="https://beacon.krxd.net/optout_check?callback=Krux.ns.costargroupincparent.kxjsonp_optOutCheck" type="text/javascript">
#   </script>
#   <script src="https://consumer.krxd.net/consent/get/7b047035-d53d-4cbd-be67-f17f8b327f81?idt=device&amp;dt=kxcookie&amp;callback=Krux.ns.costargroupincparent.kxjsonp_consent_get_0" type="text/javascript">
#   </script>
#   <script async="true" data-owner="criteo-tag" src="https://sslwidget.criteo.com/event?a=27501&amp;v=5.3.0&amp;p0=e%3Dexd%26site_type%3Dd&amp;p1=e%3Dvs%26ui_city%3D%26ui_state%3D&amp;p2=e%3Dce%26m%3D%255B%255D&amp;p3=e%3Dvl%26p%3D%255Bc58v4yf%252Cge2g3mz%252C4crt54h%255D&amp;p4=e%3Ddis&amp;adce=1&amp;lwid=1dcbe02a-8174-4bc6-82a6-8b49fd85d457&amp;tld=apartments.com&amp;dtycbr=66593" type="text/javascript">
#   </script>
#   <script async="" src="//cdn.krxd.net/ctjs/controltag.js.05f9d0dad02f8a1b0b028b868bc3a3e2">
#   </script>
#   <script async="" src="https://cdn.segment.com/analytics.js/v1/Epo5U3sC6yWr7vf2GT8PaAmgsw2LJc6q/analytics.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.krxd.net/controltag/tucpweceq.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="//bat.bing.com/bat.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://s.yimg.com/wi/ytc.js">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/plugins/inferredEvents.js?v=2.8.51">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/165133063922593?v=2.8.51&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;libraries=geometry,places&amp;v=3.34&amp;callback=MapLoaded" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5CC6LZ6">
#   </script>
#   <script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-TS2M8NB&amp;cid=247434901.1564172278" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    if (window.location.hash) {
#         var hash = window.location.hash.substr(1);
#         if (hash &amp;&amp; hash.indexOf('/') == 0) {
#             window.location.href = window.location.protocol + '//' + window.location.host + hash;
#         }
#     }
#   </script>
#   <script>
#    bazadebezolkohpepadr="2025935337"
#   </script>
#   <script defer="" src="https://www.apartments.com/akam/11/78c15342" type="text/javascript">
#   </script>
#   <style type="text/css">
#   </style>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/common.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/util.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/map.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/overlay.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .gm-style {
#         font: 400 11px Roboto, Arial, sans-serif;
#         text-decoration: none;
#       }
#       .gm-style img { max-width: none; }
#   </style>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/onion.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/stats.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps/api/js/ViewportInfoService.GetViewportInfo?1m6&amp;1m2&amp;1d37.04208551699828&amp;2d-78.16191322116191&amp;2m2&amp;1d38.00704740861756&amp;2d-76.82341769407708&amp;2u11&amp;4sen-US&amp;5e0&amp;6sm%40476000000&amp;7b0&amp;8e0&amp;callback=_xdc_._g59ose&amp;key=AIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;token=57655" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/data.js" type="text/javascript">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1067843949/?random=1564172279384&amp;cv=9&amp;fst=1564172279384&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg7i2&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F&amp;tiba=Apartments%20for%20Rent%20in%20Richmond%20VA%20%7C%20Apartments.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/933808564/?random=1564172279393&amp;cv=9&amp;fst=1564172279393&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=864&amp;u_w=1536&amp;u_ah=824&amp;u_aw=1536&amp;u_cd=24&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg7i2&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F&amp;tiba=Apartments%20for%20Rent%20in%20Richmond%20VA%20%7C%20Apartments.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps/vt?pb=!1m4!1m3!1i11!2i581!3i792!1m4!1m3!1i11!2i581!3i793!1m4!1m3!1i11!2i581!3i794!1m4!1m3!1i11!2i582!3i792!1m4!1m3!1i11!2i582!3i793!1m4!1m3!1i11!2i583!3i792!1m4!1m3!1i11!2i583!3i793!1m4!1m3!1i11!2i582!3i794!1m4!1m3!1i11!2i583!3i794!1m4!1m3!1i11!2i584!3i792!1m4!1m3!1i11!2i584!3i793!1m4!1m3!1i11!2i584!3i794!2m3!1e0!2sm!3i476185612!3m14!2sen-US!3sUS!5e18!12m1!1e68!12m3!1e37!2m1!1ssmartmaps!12m4!1e26!2m2!1sstyles!2zcy50OjMzfHMuZTpsfHAudjpvZmYscy50OjJ8cy5lOmx8cC52Om9mZixzLnQ6NHxzLmU6bHxwLnY6b2Zm!4e3!12m1!5b1&amp;callback=_xdc_._svold4&amp;key=AIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;token=27689" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/poly.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/36/12a/controls.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps/api/js/AuthenticationService.Authenticate?1shttps%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F&amp;4sAIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;callback=_xdc_._x56iso&amp;key=AIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;token=76333" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps/api/js/QuotaService.RecordEvent?1shttps%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F&amp;3sAIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;7skjsgbs&amp;10e1&amp;callback=_xdc_._t6ubx4&amp;key=AIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&amp;token=67959" type="text/javascript">
#   </script>
#  </head>
#  <body class="desktop">
#   <div class="mainWrapper">
#    <header class="mainHeader" id="mainHeader">
#     <nav class="mainHeaderNavigation" id="mainHeaderNavigation">
#      <div class="menuSection">
#       <button class="dropdownToggle primary homeBtn" id="headerMenuLink" type="button">
#        <i class="hamburgerIcon">
#        </i>
#        <span>
#         Menu
#        </span>
#       </button>
#       <div class="menuNavWrapper" id="menuNavWrapper">
#        <div id="menuNavContainer">
#         <div class="menuOpenWrapper">
#          <span class="menuHeader" id="menuHeader">
#           <i class="hamburgerIcon">
#           </i>
#           <span class="menuText">
#            Menu
#           </span>
#          </span>
#          <ul class="menuNavigation" id="menuNavigation">
#           <li>
#            <a class="expandable" data-requirelogin="false" href="#">
#             Renter Tools
#             <i class="profileCarouselArrowRightIcon">
#             </i>
#            </a>
#            <ul class="submenu tools">
#             <li>
#              <a href="https://www.apartments.com/my-account/#FavoriteListings">
#               Favorites
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/my-account/#SavedSearches">
#               Saved Searches
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li id="menuNavLnkUserNotificationSettings">
#            <a href="https://www.apartments.com/customers/" rel="nofollow">
#             Customer Tools
#            </a>
#           </li>
#           <li>
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/">
#             Apartments For Rent
#             <i class="profileCarouselArrowRightIcon">
#             </i>
#             <i class="viewMoreIcon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li>
#              <a href="https://www.apartments.com/richmond-va/">
#               Richmond Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/petersburg-va/">
#               Petersburg Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/midlothian-va/">
#               Midlothian Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/glen-allen-va/">
#               Glen Allen Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/chester-va/">
#               Chester Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/hopewell-va/">
#               Hopewell Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/chesterfield-va/">
#               Chesterfield Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/mechanicsville-va/">
#               Mechanicsville Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/colonial-heights-va/">
#               Colonial Heights Apartments For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/henrico-va/">
#               Henrico Apartments For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/houses/">
#             Homes For Rent
#             <i class="profileCarouselArrowRightIcon">
#             </i>
#             <i class="viewMoreIcon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li>
#              <a href="https://www.apartments.com/houses/richmond-va/">
#               Richmond Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/petersburg-va/">
#               Petersburg Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/midlothian-va/">
#               Midlothian Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/hopewell-va/">
#               Hopewell Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/glen-allen-va/">
#               Glen Allen Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/chesterfield-va/">
#               Chesterfield Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/chester-va/">
#               Chester Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/colonial-heights-va/">
#               Colonial Heights Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/ruther-glen-va/">
#               Ruther Glen Homes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/houses/locust-grove-va/">
#               Locust Grove Homes For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/condos/">
#             Condos For Rent
#             <i class="profileCarouselArrowRightIcon">
#             </i>
#             <i class="viewMoreIcon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li>
#              <a href="https://www.apartments.com/condos/richmond-va/">
#               Richmond Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/petersburg-va/">
#               Petersburg Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/the-fan-richmond-va/">
#               The Fan Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/church-hill-richmond-va/">
#               Church Hill Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/the-museum-district-richmond-va/">
#               The Museum District Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/richmond-va-23220/">
#               Richmond, VA 23220 Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/richmond-va-23223/">
#               Richmond, VA 23223 Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/richmond-va-23221/">
#               Richmond, VA 23221 Condos For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/condos/petersburg-va-23803/">
#               Petersburg, VA 23803 Condos For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/townhomes/">
#             Townhomes For Rent
#             <i class="profileCarouselArrowRightIcon">
#             </i>
#             <i class="viewMoreIcon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li>
#              <a href="https://www.apartments.com/townhomes/richmond-va/">
#               Richmond Townhomes For Rent
#              </a>
#             </li>
#             <li>
#              <a href="https://www.apartments.com/townhomes/henrico-county-va/">
#               Henrico County Townhomes For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <a data-requirelogin="false" href="https://www.apartments.com/mobile/" id="menuNavLnkMobileApps" target="_blank">
#             Mobile Apps
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="headerSwitchLanguageWrapper">
#       <a class="headerSwitchLanguage" data-culture="es-US" data-url="https://www.apartments.com/es/richmond-va/" href="https://www.apartments.com/es/richmond-va/" title="Español">
#        <i class="worldIcon">
#        </i>
#        Español
#       </a>
#      </div>
#      <div class="logoSpacer">
#      </div>
#      <div class="logo">
#       <a href="https://www.apartments.com/">
#        <img alt="Apartments.com Logo" src="/a/4d9af0/content/images/apartments-for-rent-logo.png"/>
#       </a>
#      </div>
#      <div class="notifications-wrapper">
#       <div class="notifications-favorites" id="notificationsFavorites" title="Favorites">
#        <i class="heartOutlineIcon icon">
#        </i>
#        <span class="notifications-count" id="notificationsFavoritesCount">
#        </span>
#        <span class="label">
#         Favorites
#        </span>
#        <i class="circleCloseIcon">
#        </i>
#       </div>
#       <div class="notifications-new-listings-alerts" id="tooltipItemNewListings" listings="" title="New">
#        <i class="alertLightning3Icon icon">
#        </i>
#        <span class="notifications-count" id="newListingCount">
#         99+
#        </span>
#        <span class="label">
#         New
#        </span>
#        <i class="circleCloseIcon">
#        </i>
#       </div>
#       <div class="notifications-alerts" id="tooltipItemNotifications" title="Alerts">
#        <div class="bell-container">
#         <i class="alertBell3Icon icon">
#         </i>
#         <div class="notifications-circle" id="notificationsCircle" style="display: none;">
#         </div>
#        </div>
#        <span class="label">
#         Alerts
#        </span>
#        <i class="circleCloseIcon">
#        </i>
#       </div>
#      </div>
#      <div class="loginPrevNextWrapper">
#       <div class="loginSection" id="headerLoginSection">
#        <a class="js-headerSignUp headerSignUp" href="javascript:void(0);" title="Sign Up">
#         Sign Up
#        </a>
#        <span>
#         /
#        </span>
#        <a class="js-headerSignin headerSignIn" href="javascript:void(0);" title="Sign In">
#         Sign In
#        </a>
#       </div>
#      </div>
#      <a href="javascript:void(0);" id="headerAddListing" title="Add a Listing">
#       <span>
#        Add a Listing
#       </span>
#      </a>
#     </nav>
#    </header>
#    <script type="application/ld+json">
#     {"@type":"SearchResultsPage","contentLocation":{"containedIn":{"@type":"State","name":"VA"},"@type":"City","name":"Richmond"},"breadcrumb":[{"itemListElement":[{"@type":"ListItem","position":0,"item":{"name":"Home","@id":"https://www.apartments.com/"}},{"@type":"ListItem","position":1,"item":{"name":"Virginia","@id":"https://www.apartments.com/va/"}},{"@type":"ListItem","position":2,"item":{"name":"Richmond Apartments for Rent","@id":"https://www.apartments.com/richmond-va/"}}],"@context":"http://schema.org","@type":"BreadcrumbList"}],"speakable":{"@type":"SpeakableSpecification","cssSelector":["#marketingBlurb &gt; p"],"xpath":["/html/head/meta[@name='description']/@content"]},"about":[{"url":"https://www.apartments.com/the-locks-tower-richmond-va/c58v4yf/","image":"https://images1.apartments.com/i2/gJEDmm31mf6bhGriLioi0tqm1-71m02ARlmXDwziRLw/117/the-locks-tower-richmond-va-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"1001 E Byrd St","addressLocality":"Richmond","addressRegion":"VA","postalCode":"23219","addressCountry":"US"},"telephone":"+1-804-205-1868","@type":"ApartmentComplex","name":"The Locks Tower","@id":"https://www.apartments.com/the-locks-tower-richmond-va/c58v4yf/"},{"url":"https://www.apartments.com/somerset-glen-richmond-va/ge2g3mz/","image":"https://images1.apartments.com/i2/1xZWKkAAs7Sh5SxYYVGIkEb6ftbXU8NvL8JBoKM0WAs/117/somerset-glen-richmond-va-kitchen.jpg","Address":{"@type":"PostalAddress","streetAddress":"406 Westover Hills Blvd","addressLocality":"Richmond","addressRegion":"VA","postalCode":"23225","addressCountry":"US"},"telephone":"+1-804-767-3547","@type":"ApartmentComplex","name":"Somerset Glen","@id":"https://www.apartments.com/somerset-glen-richmond-va/ge2g3mz/"},{"url":"https://www.apartments.com/colonial-apartments-richmond-va/4crt54h/","image":"https://images1.apartments.com/i2/mr9QIJCCzMLQ72ymTPmJaEdhSNBEkMIhyBizxe5CA4Y/117/colonial-apartments-richmond-va-living-room.jpg","Address":{"@type":"PostalAddress","streetAddress":"5501 Pony Farm Dr","addressLocality":"Richmond","addressRegion":"VA","postalCode":"23227","addressCountry":"US"},"telephone":"+1-804-977-3729","@type":"ApartmentComplex","name":"Colonial Apartments","@id":"https://www.apartments.com/colonial-apartments-richmond-va/4crt54h/"},{"url":"https://www.apartments.com/hunters-ridge-richmond-va/ytp824r/","image":"https://images1.apartments.com/i2/kCSovlio31xsvaO3Abds6hUYLaIEvTxtuBi6Lspc8IY/117/hunters-ridge-richmond-va-living-room.jpg","Address":{"@type":"PostalAddress","streetAddress":"2400 Milhaven Dr","addressLocality":"Richmond","addressRegion":"VA","postalCode":"23238","addressCountry":"US"},"telephone":"+1-804-419-5955","@type":"ApartmentComplex","name":"Hunters Ridge","@id":"https://www.apartments.com/hunters-ridge-richmond-va/ytp824r/"},{"url":"https://www.apartments.com/american-tobacco-center-richmond-va/gvf4h3y/","image":"https://images1.apartments.com/i2/paniwVG6OCwnW_IEkSLy2a0pcx-uUXTqvMC3qw-EzeY/117/american-tobacco-center-richmond-va-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"119-121 N 20th St","addressLocality":"Richmond","addressRegion":"VA","postalCode":"23223","addressCountry":"US"},"telephone":"+1-844-268-9284","@type":"ApartmentComplex","name":"American Tobacco Center","@id":"https://www.apartments.com/american-tobacco-center-richmond-va/gvf4h3y/"},{"url":"https://www.apartments.com/cedar-broad-richmond-va/gem8m5z/","image":"https://images1.apartments.com/i2/LBoVsxiYD6UTTmEg-zrnVbfAqi2CPbC5Q7Wy9X2RhNg/117/cedar-broad-richmond-va-building-photo.jpg","Address":{"@type":"PostalAddress","streetAddress":"1820 E Broad St","addressLocality":"Richmond","addressRegion":"VA","postalCode":"23223","addressCountry":"US"},"telephone":"+1-844-265-0979","@type":"ApartmentComplex","name":"Cedar Broad","@id":"https://www.apartments.com/cedar-broad-richmond-va/gem8m5z/"},{"url":"https://www.apartments.com/terraces-at-manchester-richmond-va/ngsj4zm/","image":"https://images1. ...
#    </script>
#    <main>
#     <section class="searchApp" id="searchApp">
#      <header class="searchBar" id="searchBar">
#       <!--[if lte IE 9]>
# <div class="searchBarWrapper no-flex clearfix">
# <![endif]-->
#       <!--[if (gt IE 9)|!(IE)]><!-->
#       <div class="search-bar-wrapper">
#        <!--<![endif]-->
#        <a class="backToSearch primary" data-bind="visible: isBackToSearchVisible(), click: backToSearchClick" href="javascript:void(0);" id="backToSearch" style="display: none;" title="Back to Search">
#         <i class="leftArrowIcon">
#         </i>
#         <span>
#          Back to Search
#         </span>
#        </a>
#        <span class="lookup" data-bind="visible: isTypeaheadVisible()">
#         <i class="searchIcon">
#         </i>
#         <input autocomplete="off" autocorrect="false" class="searchBarLookup savedSearchVisible hasPrefilledValue" data-bind="css: { savedSearchVisible: isSavedSearchVisible() }" id="searchBarLookup" placeholder="Location or Point of Interest" type="text"/>
#        </span>
#        <span data-bind="with: rentRange, visible: isRentRangeVisible()" id="rentMinMaxRangeControl">
#         <div class="rentRangeSelector dropDownContainer" data-bind="css: { active: isOpen(), 'has-value': minRentHasValue() === true || maxRentHasValue() === true }, event: { keydown: keyDown }">
#          <a class="btn btn-default rentselector" data-bind="click: selectorClicked, clickBubble: true" role="button" title="Price" type="button">
#           <span data-bind="text: selectedDisplayValue()">
#            Price
#           </span>
#           <i class="menuArrowDown2Icon">
#           </i>
#           <i class="clearIcon" data-bind="visible: minRentHasValue() || maxRentHasValue(), click: rentRangeClear" style="display: none;">
#           </i>
#          </a>
#          <div class="dropdownContent">
#           <div class="ranges">
#            <div class="grid firstChild">
#             <div class="cell-xs-6">
#              <input class="minRentInput active" data-bind="css: { active: isMinRentActive() }, event: { focus: minRentFocus, blur: rentInputBlur }, value: minRent, clickBubble: false" maxlength="6" pattern="\$?(\d|\,)*" placeholder="Min Rent" type="tel"/>
#             </div>
#             <div class="cell-xs-6">
#              <input class="maxRentInput" data-bind="css: { active: !isMinRentActive() }, event: { focus: maxRentFocus, blur: rentInputBlur }, value: maxRent, clickBubble: false" maxlength="6" pattern="\$?(\d|\,)*" placeholder="Max Rent" type="tel"/>
#             </div>
#            </div>
#           </div>
#           <ul class="minRentOptions js-minRentOptions active" data-bind="css: { active: isMinRentActive() }, click: minRentOptionsClicked, clickBubble: false">
#            <li class="active" data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="">
#             No Min
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="500">
#             $500
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="700">
#             $700
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="900">
#             $900
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="1100">
#             $1,100
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="1300">
#             $1,300
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="1500">
#             $1,500
#            </li>
#           </ul>
#           <ul class="maxRentOptions js-maxRentOptions" data-bind="css: { active: !isMinRentActive() }, visible: !minRentHasValue(), click: maxRentOptionsClicked, clickBubble: false" id="maxRentOptions">
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1100">
#             $1,100
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1300">
#             $1,300
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1500">
#             $1,500
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1700">
#             $1,700
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="1900">
#             $1,900
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="2100">
#             $2,100
#            </li>
#            <li class="active" data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="">
#             No Max
#            </li>
#           </ul>
#           <ul class="maxRentOptions js-customMaxRentOptions" data-bind="foreach: maxRentValues, css: { active: !isMinRentActive() }, visible: minRentHasValue(), click: maxRentOptionsClicked, clickBubble: false" style="display: none;">
#            <li class="active" data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="0">
#             $0
#            </li>
#            <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="250">
#             $250
#            </li>
#            <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="500">
#             $500
#            </li>
#            <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="750">
#             $750
#            </li>
#            <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="1000">
#             $1,000
#            </li>
#            <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="1250">
#             $1,250
#            </li>
#            <li class="active" data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()" data-value="">
#             No Max
#            </li>
#           </ul>
#          </div>
#         </div>
#        </span>
#        <span data-bind="with: bedsRange, visible: isBedRangeVisible()" id="bedsMinMaxRangeControl">
#         <div class="bedsRangeSelector dropDownContainer" data-bind="css: { active: isBedsOpen(), 'has-value': minBedsHasValue() || maxBedsHasValue() }">
#          <a class="btn btn-default bedselector" data-bind="click: selectorClicked, clickBubble: true" role="button" title="Beds" type="button">
#           <span data-bind="text: selectedDisplayValue()">
#            Beds
#           </span>
#           <i class="menuArrowDown2Icon">
#           </i>
#           <i class="clearIcon" data-bind="visible: minBedsHasValue() || maxBedsHasValue(), click: bedsClear" style="display: none;">
#           </i>
#          </a>
#          <div class="dropdownContent">
#           <div class="ranges">
#            <div class="grid">
#             <div class="cell-xs-12">
#             </div>
#             <div class="cell-xs-6 minBedsInput active" data-bind="css: { active: isMinBedsActive() }, clickBubble: false">
#              <select class="min-beds-select selectpicker" data-highlightonce="true" id="min-beds-select" name="min-beds-select" style="display: none;">
#               <option value="">
#                No Min
#               </option>
#               <option value="1">
#                1
#               </option>
#               <option value="2">
#                2
#               </option>
#               <option value="3">
#                3
#               </option>
#               <option value="4">
#                4+
#               </option>
#              </select>
#              <div class="btn-group bootstrap-select min-beds-select">
#               <button class="btn dropdownToggle selectpicker btn-default" data-id="min-beds-select" data-toggle="dropdown" title="No Min" type="button">
#                <span class="filter-option pull-left">
#                 No Min
#                </span>
#                <span class="caret">
#                </span>
#               </button>
#               <div class="dropdownMenu open" role="combobox">
#                <ul class="dropdownMenu inner selectpicker" role="menu">
#                 <li class="selected" rel="0">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    No Min
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="1">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    1
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="2">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    2
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="3">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    3
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="4">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    4+
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <span class="dash-spacer">
#               -
#              </span>
#             </div>
#             <div class="cell-xs-6 maxBedsInput" data-bind="css: { active: !isMinBedsActive() }, clickBubble: false">
#              <select class="max-beds-select selectpicker" data-highlightonce="true" id="max-beds-select" name="max-beds-select" style="display: none;">
#               <option value="">
#                No Max
#               </option>
#               <option value="-1">
#                Studio
#               </option>
#               <option value="1">
#                1
#               </option>
#               <option value="2">
#                2
#               </option>
#               <option value="3">
#                3
#               </option>
#              </select>
#              <div class="btn-group bootstrap-select max-beds-select">
#               <button class="btn dropdownToggle selectpicker btn-default" data-id="max-beds-select" data-toggle="dropdown" title="No Max" type="button">
#                <span class="filter-option pull-left">
#                 No Max
#                </span>
#                <span class="caret">
#                </span>
#               </button>
#               <div class="dropdownMenu open" role="combobox">
#                <ul class="dropdownMenu inner selectpicker" role="menu">
#                 <li class="selected" rel="0">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    No Max
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="1">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    Studio
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="2">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    1
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="3">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    2
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                 <li rel="4">
#                  <a class="" style="" tabindex="0">
#                   <span class="text">
#                    3
#                   </span>
#                   <i class="glyphicon glyphicon-ok icon-ok check-mark">
#                   </i>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </span>
#        <span data-bind="with: searchType, visible: isTypeButtonVisible()" id="SHTypeControl">
#         <div id="type-selection-wrapper">
#          <a class="btn btn-default" data-bind="click: searchTypeClicked, clickBubble: true, css: {'active': isSearchTypeMenuVisible, 'has-value': hasTypeSelected()}" id="typeSelect" role="button">
#           <span class="label">
#            Type
#           </span>
#           <span data-bind="text: selectedDisplayValue()">
#           </span>
#           <i class="menuArrowDown2Icon">
#           </i>
#           <i class="clearIcon" data-bind="visible: isTypeSelected(), click: typeClear" style="display: none;">
#           </i>
#          </a>
#          <div class="drop-down-container" data-bind="visible: isSearchTypeMenuVisible(), css: {'active': isSearchTypeMenuVisible}" style="display: none;">
#           <div class="checkbox-block prop-type-1" data-path="5" data-value="1">
#            <a href="javascript:void(0);" title="">
#             <input class="primaryCheckbox type_1" data-bind="disable: hasNoTypeFacets($element)" data-path="Listing.Style" data-value="1" id="StyleSmall_1" type="checkbox" value="1"/>
#             <label for="StyleSmall_1">
#              <span>
#               Apartments
#              </span>
#              <span class="facetCount" id="type_1">
#               (3,239)
#              </span>
#             </label>
#            </a>
#           </div>
#           <div class="checkbox-block prop-type-2" data-path="5" data-value="2">
#            <a href="https://www.apartments.com/houses/richmond-va/" title="">
#             <input class="primaryCheckbox type_2" data-bind="disable: hasNoTypeFacets($element)" data-path="Listing.Style" data-value="2" id="StyleSmall_2" type="checkbox" value="2"/>
#             <label for="StyleSmall_2">
#              <span>
#               Houses
#              </span>
#              <span class="facetCount" id="type_2">
#               (162)
#              </span>
#             </label>
#            </a>
#           </div>
#           <div class="checkbox-block prop-type-4" data-path="5" data-value="4">
#            <a href="https://www.apartments.com/condos/richmond-va/" title="">
#             <input class="primaryCheckbox type_4" data-bind="disable: hasNoTypeFacets($element)" data-path="Listing.Style" data-value="4" id="StyleSmall_4" type="checkbox" value="4"/>
#             <label for="StyleSmall_4">
#              <span>
#               Condos
#              </span>
#              <span class="facetCount" id="type_4">
#               (14)
#              </span>
#             </label>
#            </a>
#           </div>
#           <div class="checkbox-block prop-type-16" data-path="5" data-value="16">
#            <a href="https://www.apartments.com/townhomes/richmond-va/" title="">
#             <input class="primaryCheckbox type_16" data-bind="disable: hasNoTypeFacets($element)" data-path="Listing.Style" data-value="16" id="StyleSmall_16" type="checkbox" value="16"/>
#             <label for="StyleSmall_16">
#              <span>
#               Townhomes
#              </span>
#              <span class="facetCount" id="type_16">
#               (12)
#              </span>
#             </label>
#            </a>
#           </div>
#          </div>
#         </div>
#        </span>
#        <span data-bind="with: lifestyle, visible: isLifestyleButtonVisible()" id="lifestyleControl">
#         <a data-bind="click: lifestyleClicked, clickBubble: true, css: {'active': isLifestyleMenuVisible(), 'has-value': isLifestyleSelected()}" id="lifestyleSelect" role="button">
#          <span class="label" data-bind="visible: isLifestyleLabelVisible()">
#           Lifestyle
#          </span>
#          <span data-bind="text: selectedLifestyleValue()">
#          </span>
#          <i class="menuArrowDown2Icon">
#          </i>
#          <i class="clearIcon" data-bind="visible: isLifestyleSelected(), click: lifestyleClear" style="display: none;">
#          </i>
#          <span class="magic-bar-dongle">
#           <div class="arrow">
#           </div>
#          </span>
#         </a>
#         <span class="drop-down-container" data-bind="visible: isLifestyleMenuVisible(), css: {'active': isLifestyleMenuVisible()}" style="display: none;">
#          <span class="radioGroup">
#           <span class="radio-block lifestyle-4">
#            <a href="https://www.apartments.com/richmond-va/student-housing/" title="">
#             <input class="primaryRadio lifestyle-selectpicker lifestyle_4" data-bind="disable: hasNoLifestyleFacets($element)" id="Student" name="lifestyle-select" type="radio" value="4"/>
#             <label for="Student">
#              <span>
#               Student
#              </span>
#              <span class="facetCount" id="lifestyle_4">
#               (2,164)
#              </span>
#             </label>
#            </a>
#           </span>
#           <span class="radio-block lifestyle-1">
#            <a href="https://www.apartments.com/richmond-va/senior-housing/" title="">
#             <input class="primaryRadio lifestyle-selectpicker lifestyle_1" data-bind="disable: hasNoLifestyleFacets($element)" id="Senior Housing" name="lifestyle-select" type="radio" value="1"/>
#             <label for="Senior Housing">
#              <span>
#               Senior Housing
#              </span>
#              <span class="facetCount" id="lifestyle_1">
#               (63)
#              </span>
#             </label>
#            </a>
#           </span>
#           <span class="radio-block lifestyle-16">
#            <a href="https://www.apartments.com/richmond-va/short-term/" title="">
#             <input class="primaryRadio lifestyle-selectpicker lifestyle_16" data-bind="disable: hasNoLifestyleFacets($element)" id="Short Term" name="lifestyle-select" type="radio" value="16"/>
#             <label for="Short Term">
#              <span>
#               Short Term
#              </span>
# ...
#                 sortOptions: [{"Item1":0,"Item2":"Sort","Item3":"Default"},{"Item1":2,"Item2":"Rent","Item3":"Rent (low to high)"},{"Item1":1,"Item2":"Rent","Item3":"Rent (high to low)"},{"Item1":4,"Item2":"Video","Item3":"Video"},{"Item1":6,"Item2":"3D Tour","Item3":"3D Tour"},{"Item1":8,"Item2":"Last Updated","Item3":"Last Updated"}],
#                 redirectState: null,
#                 myApplicationsUrl: 'https://www.apartments.com/my-account/#MyApplications'
#             });
#         });
#   </script>
#   <link href="/Modules/Profile/Content/style.bundle.css?v=K_I-ES9pWFxGhhKDsenw_UZQhwblGXKkl5gfskUBVX0" rel="prefetch"/>
#   <link href="/Modules/Profile/Scripts/profile.shared.bundle.js?v=azTxXo0dOwLzK29jPzdcL7Z4OjrVQgy4sfzQ4Hrthhw" rel="prefetch"/>
#   <noscript>
#    &lt;img src="https://www.apartments.com/akam/11/pixel_78c15342?a=dD05YWE0YTJhM2E5ODhhMTQxMjRiYTVhYjBmNmIxMjdhYjViMTMyNmI1JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;" /&gt;
#   </noscript>
#   <div id="signupContainer">
#   </div>
#   <div id="authContainer">
#   </div>
#   <div id="loginContainer">
#   </div>
#   <div id="modalContainer">
#   </div>
#   <div id="favoriteModalContainer">
#   </div>
#   <div id="savedSearchContainer">
#   </div>
#   <div id="savedSearchConfirmContainer">
#   </div>
#   <div id="modalVideoPlayerContainer">
#   </div>
#   <script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript">
#   </script>
#   <script id="" src="https://10948010.collect.igodigital.com/collect.js" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init",google_tag_manager["GTM-5CC6LZ6"].macro(4));fbq("track","PageView");
#   </script>
#   <noscript>
#    &lt;img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=165133063922593&amp;amp;ev=PageView&amp;amp;noscript=1"&gt;
#   </noscript>
#   <script id="" type="text/javascript">
#    (function(d,a,b,f,e){d[e]=d[e]||[];d[e].push({projectId:google_tag_manager["GTM-5CC6LZ6"].macro(5),properties:{pixelId:google_tag_manager["GTM-5CC6LZ6"].macro(6)}});var c=a.createElement(b);c.src=f;c.async=!0;c.onload=c.onreadystatechange=function(){var a=this.readyState,c=d[e];if(!a||"complete"==a||"loaded"==a)try{var b=YAHOO.ywa.I13N.fireBeacon;d[e]=[];d[e].push=function(a){b([a])};b(c)}catch(g){}};a=a.getElementsByTagName(b)[0];b=a.parentNode;b.insertBefore(c,a)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");
#   </script>
#   <script id="" type="text/javascript">
#    window.Krux||((Krux=function(){Krux.q.push(arguments)}).q=[]);(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src=("https:"===location.protocol?"https:":"http:")+"//cdn.krxd.net/controltag/tucpweceq.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();
#   </script>
#   <script id="" type="text/javascript">
#    !function(){var a=window.analytics=window.analytics||[];if(!a.initialize)if(a.invoked)window.console&amp;&amp;console.error&amp;&amp;console.error("Segment snippet included twice.");else{a.invoked=!0;a.methods="trackSubmit trackClick trackLink trackForm pageview identify reset group track ready alias debug page once off on".split(" ");a.factory=function(b){return function(){var d=Array.prototype.slice.call(arguments);d.unshift(b);a.push(d);return a}};for(var b=0;b&lt;a.methods.length;b++){var c=a.methods[b];a[c]=a.factory(c)}a.load=
# function(b,d){var e=document.createElement("script");e.type="text/javascript";e.async=!0;e.src="https://cdn.segment.com/analytics.js/v1/"+b+"/analytics.min.js";var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(e,c);a._loadOptions=d};a.SNIPPET_VERSION="4.1.0";a.load("Epo5U3sC6yWr7vf2GT8PaAmgsw2LJc6q");a.page()}}();
#   </script>
#   <script id="" src="https://c.tvpixel.com/js/current/dpm_pixel_min.js?aid=apartments-com-e62f8ea9-7850-4c7c-99df-5d60c689fc30" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    window.criteo_q=window.criteo_q||[];window.criteo_q.push({event:"setAccount",account:google_tag_manager["GTM-5CC6LZ6"].macro(7)},{event:"setSiteType",type:google_tag_manager["GTM-5CC6LZ6"].macro(8)},{event:"viewSearch",ui_city:google_tag_manager["GTM-5CC6LZ6"].macro(9),ui_state:google_tag_manager["GTM-5CC6LZ6"].macro(10)},{event:"setHashedEmail",email:google_tag_manager["GTM-5CC6LZ6"].macro(11)},{event:"viewList",item:(google_tag_manager["GTM-5CC6LZ6"].macro(12)||[]).slice(0,3)});
#   </script>
#   <script id="" type="text/javascript">
#    if(window.fbq){var data=(google_tag_manager["GTM-5CC6LZ6"].macro(13)||[]).slice(0,10);fbq("track","Search",{content_ids:data,availability:"for_rent",city:google_tag_manager["GTM-5CC6LZ6"].macro(14),region:google_tag_manager["GTM-5CC6LZ6"].macro(15),country:"United States",content_type:["product","home_listing"]})};
#   </script>
#   <script id="" type="text/javascript">
#    window._etmc=window._etmc||[];var searchValue=google_tag_manager["GTM-5CC6LZ6"].macro(17)||(google_tag_manager["GTM-5CC6LZ6"].macro(18)&amp;&amp;google_tag_manager["GTM-5CC6LZ6"].macro(19)?google_tag_manager["GTM-5CC6LZ6"].macro(20)+","+google_tag_manager["GTM-5CC6LZ6"].macro(21):null);window._etmc.push(["setOrgId",google_tag_manager["GTM-5CC6LZ6"].macro(22)]);window._etmc.push(["setUserInfo",{email:google_tag_manager["GTM-5CC6LZ6"].macro(23)}]);window._etmc.push(["trackPageView",{search:searchValue}]);
#   </script>
#   <div id="batBeacon0.19641217303977965" style="width:0px; height:0px; display:none; visibility:hidden;">
#    <img alt="" height="0" id="batBeacon0.43120745374982095" src="https://bat.bing.com/action/0?ti=4070025&amp;Ver=2&amp;mid=c757bd0e-b512-5be7-1ccf-1a629c6f17f9&amp;pi=1200101525&amp;lg=en-US&amp;sw=1536&amp;sh=864&amp;sc=24&amp;tl=Apartments%20for%20Rent%20in%20Richmond%20VA%20%7C%20Apartments.com&amp;p=https%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F&amp;r=&amp;lt=2505&amp;evt=pageLoad&amp;msclkid=N&amp;rn=461396" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/>
#   </div>
#   <div style="display: none;">
#    <img aria-hidden="true" height="0" src="https://nova.collect.igodigital.com/c2/10948010/track_page_view?payload=%7B%22search%22%3A%22Richmond%2C%20VA%22%2C%22title%22%3A%22Apartments%20for%20Rent%20in%20Richmond%20VA%20%7C%20Apartments.com%22%2C%22url%22%3A%22https%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F%22%2C%22referrer%22%3A%22%22%2C%22user_info%22%3A%7B%7D%7D" style="display: none;" title="blank image" width="0"/>
#   </div>
#   <script class="ywa-10000" defer="" id="ywa-1564172279822-799199" src="https://sp.analytics.yahoo.com/sp.pl?a=10000&amp;jsonp=YAHOO.ywa.I13N.handleJSONResponse&amp;d=Fri%2C%2026%20Jul%202019%2020%3A17%3A59%20GMT&amp;n=4d&amp;b=Apartments%20for%20Rent%20in%20Richmond%20VA%20%7C%20Apartments.com&amp;.yp=10025934&amp;f=https%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F&amp;enc=UTF-8" type="application/javascript">
#   </script>
#   <div class="kxhead" data-id="tucpweceq" style="display:none !important;">
#    <span class="kxtag kxinvisible" data-id="39496">
#     <script>
#      (function() {
#     /* Standard but configurable DTC */
#     var comDomain, domain, level, libUtil, pathLevel, prefix, toSet;
#     libUtil = Krux('require:util.library-tag');
#     toSet = {};
#     level = 1;
#     while (level &lt;= Number('6')) {
#         pathLevel = Krux('scrape.url_path', level);
#         if (pathLevel) {
#             if ('true' === 'true') {
#                 pathLevel = ("" + pathLevel).replace(
#                     /\.(?:html?|php[0-9]?|aspx?|cfg|py)$/i, '');
#             }
#             toSet["page_attr_url_path_" + level] = pathLevel;
#         }
#         level++;
#     }
#     toSet['page_attr_meta_keywords'] = Krux('scrape.meta_name', 'keywords');
#     prefix = libUtil.resolvePrefix('none', 'undefined',
#         'undefined');
#     toSet = Krux('prefix:attr', toSet, prefix);
#     domain = Krux('get', 'domain');
#     comDomain = domain.match(/\.([^\.]+\.com)$/);
#     if (comDomain) {
#         domain = comDomain[1];
#     }
#     toSet['page_attr_domain'] = domain;
#     Krux('set', toSet);
# }).call();
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="40916">
#     <script>
#      (function() {
#     /* Generic Scrape Tag - Configurable Data Collection */
#     var _, filterValues, libUtil, prefix, scrapeConfig, toSet;
#     _ = Krux('require:underscore');
#     libUtil = Krux('require:util.library-tag');
#     toSet = {};
#     filterValues = function(val) {
#         var i, item, len, ref, str, x;
#         if (_.isArray(val)) {
#             return _.compact((function() {
#                 var i, len, results;
#                 results = [];
#                 for (i = 0, len = val.length; i &lt; len; i++) {
#                     item = val[i];
#                     results.push(filterValues(item));
#                 }
#                 return results;
#             })());
#         }
#         str = "" + val;
#         if (!((val != null) &amp;&amp; str.length &gt; 0)) {
#             return;
#         }
#         ref = libUtil.EXCLUDE_VALUES_CONFIG;
#         for (i = 0, len = ref.length; i &lt; len; i++) {
#             x = ref[i];
#             if (str.match(x) != null) {
#                 return;
#             }
#         }
#         return val;
#     };
#     scrapeConfig = function(config, type) {
#         var attr, i, len, parts, ref, results, value;
#         ref = libUtil.removeFalsyStrings(config);
#         results = [];
#         for (i = 0, len = ref.length; i &lt; len; i++) {
#             attr = ref[i];
#             parts = attr.split('|');
#             if (parts.length === 1 &amp;&amp; 'dataLayer'.match(/(dom|javascript)/)) {
#                 continue;
#             }
#             if (parts.length === 1) {
#                 parts.unshift(libUtil.normalizeAttrName(parts[0]));
#             }
#             switch ('dataLayer') {
#                 case 'get':
#                     value = filterValues(Krux('get', parts[1]));
#                     break;
#                 default:
#                     value = filterValues(Krux('scrape.dataLayer', parts[1]));
#             }
#             if (value) {
#                 results.push(toSet[type + "_attr_" + parts[0]] = value);
#             } else {
#                 results.push(void 0);
#             }
#         }
#         return results;
#     };
#     scrapeConfig('property_id|listingKey,property_id|clickedListingKey,ad_package|listingTypeId,companyKey|companyKey,name|event', 'page');
#     scrapeConfig('undefined', 'user');
#     prefix = libUtil.resolvePrefix('none', 'undefined',
#         'undefined');
#     toSet = Krux('prefix:attr', toSet, prefix);
#     Krux('set', toSet);
# }).call();
#     </script>
#    </span>
#    <span class="kxtag kxinvisible" data-id="40998">
#     <script>
#      (function(){
#     Krux('set', 'page_attr_profile_listing_city_state', Krux('scrape.dataLayer', 'ui_city') + ', ' + Krux('scrape.dataLayer', 'ui_state'))
# })()
#     </script>
#    </span>
#   </div>
#   <div id="criteo-tags-div" style="display: none;">
#    <iframe height="0" src="//dis.us.criteo.com/dis/dis.aspx?p=27501&amp;cb=78438643381&amp;ref=&amp;sc_r=1536x864&amp;sc_d=24" style="display: none;" title="Criteo DIS iframe" width="0">
#    </iframe>
#   </div>
#   <iframe height="0" src="//6337982.fls.doubleclick.net/activityi;src=6337982;type=aptstraf;cat=apart00;ord=5917291764476;gtm=2wg7i2;auiddc=245746533.1564172279;~oref=https%3A%2F%2Fwww.apartments.com%2Frichmond-va%2F?" style="display: none; visibility: hidden;" width="0">
#   </iframe>
#  </body>
#  <iframe id="kx-proxy-tucpweceq" src="https://cdn.krxd.net/partnerjs/xdi/proxy.3d2100fd7107262ecb55ce6847f01fa5.html#!kxcid=tucpweceq&amp;kxt=https%3A%2F%2Fwww.apartments.com&amp;kxcl=cdn&amp;kxp=" style="display: none; visibility: hidden; height: 0; width: 0;">
#  </iframe>
# </html>

# %%
count = 1
pages = []
for page in range(2):
    page_url = f"{apartments_url}{count}"
    count = count + 1
    pages.append(page_url)
    print(page_url)
# Out:
# https://www.apartments.com/richmond-va/1
# https://www.apartments.com/richmond-va/2

# %%
print(pages)
# Out:
# ['https://www.apartments.com/richmond-va/1', 'https://www.apartments.com/richmond-va/2']

# %%
apartments = apartments_soup.find_all('article', class_='diamond placard')
apartment_info = []

# %%
def listToString(Zipcode):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in Zipcode:  
        str1 = ele   
    
    # return string   
    return str1

# %%
for page in pages:
    browser.visit(page)
    apartments_html = browser.html
    page_soup = bs(apartments_html, 'html.parser')
    apartments = page_soup.find_all('article', class_='diamond placard')
    for apartment in apartments:
        name = apartment.find('a').text
        Name = name.replace('\n','')
        link = apartment.find('a')['href']
        location = apartment.find('div', class_='location').text
        Zipcode = [ele for ele in Richmond_zipcodes if(ele in location)]
        Zipcode_string = listToString(Zipcode)
        cost = apartment.find('span', class_='altRentDisplay').text

        browser.visit(link)
        apartment_link_html = browser.html
        apartment_link_soup = bs(apartment_link_html, 'html.parser')

        phone = apartment_link_soup.find('span', class_='phoneNumber').text
        Phone_Number = phone.replace('\n\n','').replace('\n','')
        Rating = apartment_link_soup.find('span', class_='rating-tooltip')
        if Rating != None:
            Rating = float(str(Rating).replace('<span class="rating-tooltip">', '').replace(' star property</span>', ''))
        
        school_Type = apartment_link_soup.find('p', class_='schoolType').text
        school_name = apartment_link_soup.find('p', class_='schoolName').text
        grade_levels = apartment_link_soup.find('p', class_='grades').text
        numb_of_students = apartment_link_soup.find('p', class_='numberOfStudents').text
        school_phone = apartment_link_soup.find('p', class_='schoolPhone').text

        apartment_amenities = apartment_link_soup.find_all('section', class_='amenitiesSection') 

        for amenities in apartment_amenities:
            pet_policy = amenities.find_all('div', class_='petPolicyDetails')
            for pet in pet_policy:
                pet = pet.find('span').text
                #if pet == 'Dogs and Cats Allowed': 
                    #print('Dogs and Cats Allowed')
                    #Dogs_allowed = 'Dogs Allowed'
                    #Cats_allowed = 'Cats Allowed'
                #elif pet == 'Dogs and Cats Allowed:': 
                    #print('Dogs + Cats Allowed')
                    #Dogs_allowed = 'Dogs Allowed'
                   # Cats_allowed = 'Cats Allowed'
               # elif pet == 'Dogs Allowed' or 'Dogs Allowed:' and pet == 'Cats Allowed' or 'Cats Allowed:': 
                   # print('Dogs/cats allowed')
                    #Dogs_allowed = 'Dogs Allowed'
                    #Cats_allowed = 'Cats Allowed'
                #else pet == 'No Pets Allowed':
                   # Dogs_allowed = 'No Dogs Allowed'
                   # Cats_allowed = 'No Cats Allowed'
                    

        apartment_info.append({'Name': Name, 'Apartment_link' : link, 'Address': location, \
                               'Zipcode': Zipcode_string, 'phone_number': Phone_Number, 'price_range': cost,
                               'rating': Rating, 'Type': school_Type, 'School Name': school_name, 'Grade Levels': grade_levels, \
                               'Student Count': numb_of_students, 'Phone': school_phone})
#print(name)
print('--------------------')
#print(link)
#print('--------------------')
#print(location)
#print('--------------------')
#print(phone)
#print('--------------------')
#print(cost)
#print('--------------------')
#print(rating)
# Out:
# 2.7
# 3.8
# 3.5
# 3.9
# 5.0
# 4.7
# 4.0
# 5.0
# 5.0
# 4.0
# 3.9
# 4.1
# 4.0
# 5.0
# 5.0
# 4.9
# 3.9
# 5.0
# 4.0
# 4.0
# 5.0
# 3.8
# 5.0
# 4.0
# 5.0
# 3.2
# 3.6
# 4.0
# 4.7
# 3.8
# 4.0
# 4.0
# 3.7
# 4.9
# 3.0
# 3.9
# 4.9
# --------------------

# %%
apartment_info
# Out:
# [{'Name': 'The Locks Tower',
#   'Apartment_link': 'https://www.apartments.com/the-locks-tower-richmond-va/c58v4yf/',
#   'Address': '1001 E Byrd St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '804-205-1868',
#   'price_range': '$1,124 - 5,650',
#   'rating': None,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': '',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Somerset Glen',
#   'Apartment_link': 'https://www.apartments.com/somerset-glen-richmond-va/ge2g3mz/',
#   'Address': '406 Westover Hills Blvd, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '804-767-3547',
#   'price_range': '$720 - 890',
#   'rating': 2.7,
#   'Type': 'Public Elementary School',
#   'School Name': 'Westover Hills Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '434 Students',
#   'Phone': '(804) 780-5002'},
#  {'Name': 'Colonial Apartments',
#   'Apartment_link': 'https://www.apartments.com/colonial-apartments-richmond-va/4crt54h/',
#   'Address': '5501 Pony Farm Dr, Richmond, VA 23227',
#   'Zipcode': '23227',
#   'phone_number': '804-977-3729',
#   'price_range': '$720 - 1,140',
#   'rating': 3.8,
#   'Type': 'Public Elementary School',
#   'School Name': 'Laburnum Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '627 Students',
#   'Phone': '(804) 228-2720'},
#  {'Name': 'Hunters Ridge',
#   'Apartment_link': 'https://www.apartments.com/hunters-ridge-richmond-va/ytp824r/',
#   'Address': '2400 Milhaven Dr, Richmond, VA 23238',
#   'Zipcode': '23238',
#   'phone_number': '804-419-5955',
#   'price_range': '$1,030 - 1,195',
#   'rating': 3.5,
#   'Type': 'Public Elementary School',
#   'School Name': 'Ruby F. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '550 Students',
#   'Phone': '(804) 750-2640'},
#  {'Name': 'American Tobacco Center',
#   'Apartment_link': 'https://www.apartments.com/american-tobacco-center-richmond-va/gvf4h3y/',
#   'Address': '119-121 N 20th St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-268-9284',
#   'price_range': '$931 - 2,354',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Cedar Broad',
#   'Apartment_link': 'https://www.apartments.com/cedar-broad-richmond-va/gem8m5z/',
#   'Address': '1820 E Broad St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-265-0979',
#   'price_range': '$860 - 1,785',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Terraces at Manchester',
#   'Apartment_link': 'https://www.apartments.com/terraces-at-manchester-richmond-va/ngsj4zm/',
#   'Address': '800 Semmes Ave, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '844-615-8171',
#   'price_range': '$1,050 - 3,500',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': 'Deco at CNB',
#   'Apartment_link': 'https://www.apartments.com/deco-at-cnb-richmond-va/2sczzjb/',
#   'Address': '219 E Broad St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '844-492-1883',
#   'price_range': '$987 - 2,342',
#   'rating': None,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': '',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Retreat at West Creek',
#   'Apartment_link': 'https://www.apartments.com/retreat-at-west-creek-richmond-va/ywbrymr/',
#   'Address': '1000 Wilkes Ridge Pl, Richmond, VA 23233',
#   'Zipcode': '23233',
#   'phone_number': '855-881-2183',
#   'price_range': '$1,313 - 3,023',
#   'rating': 4.7,
#   'Type': 'Public Elementary School',
#   'School Name': 'Randolph Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '493 Students',
#   'Phone': '(804) 556-5385'},
#  {'Name': 'Element at Stonebridge',
#   'Apartment_link': 'https://www.apartments.com/element-at-stonebridge-richmond-va/byw4yj9/',
#   'Address': '301 Karl Linn Dr, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '844-269-0814',
#   'price_range': '$1,049 - 1,479',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'A M Davis Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '689 Students',
#   'Phone': '(804) 674-1310'},
#  {'Name': 'Bloom Apartments',
#   'Apartment_link': 'https://www.apartments.com/bloom-apartments-richmond-va/658ydcs/',
#   'Address': '3211 Chamberlayne Ave, Richmond, VA 23227',
#   'Zipcode': '23227',
#   'phone_number': '844-262-0130',
#   'price_range': '$619 - 899',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Linwood Holton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '598 Students',
#   'Phone': '(804) 228-5310'},
#  {'Name': 'Overview',
#   'Apartment_link': 'https://www.apartments.com/overview-richmond-va/fsc82pv/',
#   'Address': '1817 E Main St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '888-345-1619',
#   'price_range': '$1,322 - 3,382',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'The Edge',
#   'Apartment_link': 'https://www.apartments.com/the-edge-richmond-va/88xevw0/',
#   'Address': '1914 E Franklin St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '804-316-9084',
#   'price_range': '$1,075 - 1,835',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Symbol Apartments',
#   'Apartment_link': 'https://www.apartments.com/symbol-apartments-richmond-va/vqn9pcg/',
#   'Address': '1814 Highpoint Ave, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '888-830-4568',
#   'price_range': '$1,406 - 2,492',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': '2000 West Creek',
#   'Apartment_link': 'https://www.apartments.com/2000-west-creek-richmond-va/t869k6b/',
#   'Address': '2000 Broad Branch Cir, Richmond, VA 23238',
#   'Zipcode': '23238',
#   'phone_number': '888-788-7915',
#   'price_range': '$1,215 - 3,380',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Randolph Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '493 Students',
#   'Phone': '(804) 556-5385'},
#  {'Name': "River's Edge at Manchester",
#   'Apartment_link': 'https://www.apartments.com/rivers-edge-at-manchester-richmond-va/fxj7qrr/',
#   'Address': '505 Porter St, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '804-396-6534',
#   'price_range': '$1,199 - 4,364',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': "Scott's View",
#   'Apartment_link': 'https://www.apartments.com/scotts-view-richmond-va/w0vb1rk/',
#   'Address': '1400 Roseneath Rd, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '804-208-0441',
#   'price_range': '$1,170 - 1,835',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'Hardwicke House',
#   'Apartment_link': 'https://www.apartments.com/hardwicke-house-richmond-va/8q5w293/',
#   'Address': '3212 Cutshaw Ave, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '804-417-7047',
#   'price_range': 'Call for Rent',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'Fording Flats',
#   'Apartment_link': 'https://www.apartments.com/fording-flats-richmond-va/bgqwreb/',
#   'Address': '2213 E Franklin St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '804-414-8482',
#   'price_range': '$1,669',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Flats at 25th',
#   'Apartment_link': 'https://www.apartments.com/flats-at-25th-richmond-va/k9rjrl8/',
#   'Address': '2400 Fairmount Ave, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '202-851-6690',
#   'price_range': '$850 - 1,250',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'George Mason Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '452 Students',
#   'Phone': '(804) 780-4401'},
#  {'Name': 'Millspring Commons',
#   'Apartment_link': 'https://www.apartments.com/millspring-commons-richmond-va/5xmj1sn/',
#   'Address': '9318 Tarheel Ter, Richmond, VA 23228',
#   'Zipcode': '23228',
#   'phone_number': '804-496-7122',
#   'price_range': '$1,129 - 1,639',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Dumbarton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '632 Students',
#   'Phone': '(804) 756-3030'},
#  {'Name': 'Stony Point',
#   'Apartment_link': 'https://www.apartments.com/stony-point-richmond-va/gzkrhmy/',
#   'Address': '3012 Stony Lake Dr, Richmond, VA 23235',
#   'Zipcode': '23235',
#   'phone_number': '844-365-3117',
#   'price_range': '$1,164 - 1,396',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'J.B. Fisher Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '373 Students',
#   'Phone': '(804) 327-5612'},
#  {'Name': 'Harbor Village Apartments',
#   'Apartment_link': 'https://www.apartments.com/harbor-village-apartments-richmond-va/g5rd91z/',
#   'Address': '2370 Harpoon Ct, Richmond, VA 23294',
#   'Zipcode': '23294',
#   'phone_number': '866-249-6227',
#   'price_range': '$1,195 - 2,670',
#   'rating': 4.1,
#   'Type': 'Public Elementary School',
#   'School Name': 'Skipwith Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '542 Students',
#   'Phone': '(804) 527-4650'},
#  {'Name': 'Park West End',
#   'Apartment_link': 'https://www.apartments.com/park-west-end-richmond-va/shh0l77/',
#   'Address': '5300 Glenside Dr, Richmond, VA 23228',
#   'Zipcode': '23228',
#   'phone_number': '866-403-9073',
#   'price_range': '$840 - 2,045',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Johnson Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '541 Students',
#   'Phone': '(804) 673-3735'},
#  {'Name': 'East 51 At Rocketts Landing',
#   'Apartment_link': 'https://www.apartments.com/east-51-at-rocketts-landing-richmond-va/mdq1dkj/',
#   'Address': '5101-5151 Old Main St, Richmond, VA 23231',
#   'Zipcode': '23231',
#   'phone_number': '804-977-3657',
#   'price_range': '$1,138 - 2,495',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Chimborazo Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '425 Students',
#   'Phone': '(804) 780-8392'},
#  {'Name': 'Penstock Quarter Apartments',
#   'Apartment_link': 'https://www.apartments.com/penstock-quarter-apartments-richmond-va/zj5142y/',
#   'Address': '5001 Libbie Mill East Blvd, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '804-419-7621',
#   'price_range': '$1,156 - 2,684',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Johnson Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '541 Students',
#   'Phone': '(804) 673-3735'},
#  {'Name': 'Miller and Rhoads Residences',
#   'Apartment_link': 'https://www.apartments.com/miller-and-rhoads-residences-richmond-va/9qrg4l4/',
#   'Address': '230 N 6th St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '804-767-8907',
#   'price_range': '$1,575 - 2,750',
#   'rating': 5.0,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': '',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Vida East Apartments',
#   'Apartment_link': 'https://www.apartments.com/vida-east-apartments-richmond-va/r4e9343/',
#   'Address': '1903 E Marshall St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-279-4930',
#   'price_range': '$899 - 1,729',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Link Apartments Manchester',
#   'Apartment_link': 'https://www.apartments.com/link-apartments-manchester-richmond-va/dvmkr2k/',
#   'Address': '901 McDonough St, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '888-497-8838',
#   'price_range': '$1,058 - 2,627',
#   'rating': 4.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': 'The Preserve at Scotts Addition',
#   'Apartment_link': 'https://www.apartments.com/the-preserve-at-scotts-addition-richmond-va/s9bwcn6/',
#   'Address': '1310 Roseneath Rd, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '844-880-4283',
#   'price_range': '$1,112 - 2,023',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'The Locks Apartments*',
#   'Apartment_link': 'https://www.apartments.com/the-locks-apartments-richmond-va/58ek15p/',
#   'Address': '311 S 11th St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '866-954-9917',
#   'price_range': '$1,297 - 3,286',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'George W. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '474 Students',
#   'Phone': '(804) 780-6247'},
#  {'Name': 'Hickory Creek Apartments',
#   'Apartment_link': 'https://www.apartments.com/hickory-creek-apartments-richmond-va/pzevkxv/',
#   'Address': '2344 Hickory Creek Dr, Richmond, VA 23294',
#   'Zipcode': '23294',
#   'phone_number': '844-832-3044',
#   'price_range': '$990 - 1,487',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Skipwith Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '542 Students',
#   'Phone': '(804) 527-4650'},
#  {'Name': 'Copper Mill Apartments',
#   'Apartment_link': 'https://www.apartments.com/copper-mill-apartments-richmond-va/8pc5ff3/',
#   'Address': '3400 Copper Mill Trace, Richmond, VA 23294',
#   'Zipcode': '23294',
#   'phone_number': '844-293-8479',
#   'price_range': '$1,179 - 1,378',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Davis Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '552 Students',
#   'Phone': '(804) 527-4620'},
#  {'Name': 'South Bank',
#   'Apartment_link': 'https://www.apartments.com/south-bank-richmond-va/rg5rq81/',
#   'Address': '307 Stockton St, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '844-215-3652',
#   'price_range': '$987 - 1,716',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': 'The Wilton Apartments',
#   'Apartment_link': 'https://www.apartments.com/the-wilton-apartments-richmond-va/fh5jr3t/',
#   'Address': '9101 Patterson Ave, Richmond, VA 23229',
#   'Zipcode': '23229',
#   'phone_number': '844-632-5102',
#   'price_range': '$893 - 1,295',
#   'rating': 3.8,
#   'Type': 'Public Elementary School',
#   'School Name': 'Maybeury Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '676 Students',
#   'Phone': '(804) 750-2650'},
#  {'Name': 'The Gallery',
#   'Apartment_link': 'https://www.apartments.com/the-gallery-richmond-va/3jkzexd/',
#   'Address': '308 N Nansemond St, Richmond, VA 23221',
#   'Zipcode': '23221',
#   'phone_number': '844-808-5839',
#   'price_range': '$1,334',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'Avia',
#   'Apartment_link': 'https://www.apartments.com/avia-richmond-va/y96k2tv/',
#   'Address': '5200 Avia Way, Richmond, VA 23233',
#   'Zipcode': '23233',
#   'phone_number': '804-442-6424',
#   'price_range': '$1,445 - 2,809',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Kaechele Elementary',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '440 Students',
#   'Phone': '(804) 364-0055'},
#  {'Name': 'Amber Ridge Apartments',
#   'Apartment_link': 'https://www.apartments.com/amber-ridge-apartments-richmond-va/42qz4cj/',
#   'Address': '5601 Goldthread Ln, Richmond, VA 23228',
#   'Zipcode': '23228',
#   'phone_number': '804-977-3772',
#   'price_range': '$801 - 1,462',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Dumbarton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '632 Students',
#   'Phone': '(804) 756-3030'},
#  {'Name': 'Residences at the John Marshall',
#   'Apartment_link': 'https://www.apartments.com/residences-at-the-john-marshall-richmond-va/5r63gkm/',
#   'Address': '101 N 5th St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '877-414-3691',
#   'price_range': '$1,100 - 2,724',
#   'rating': 5.0,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': '',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Meadowbrook Apartments',
#   'Apartment_link': 'https://www.apartments.com/meadowbrook-apartments-richmond-va/qgtwtsy/',
#   'Address': '5314 Whetstone Rd, Richmond, VA 23234',
#   'Zipcode': '23234',
#   'phone_number': '877-661-7403',
#   'price_range': '$870 - 1,510',
#   'rating': 3.2,
#   'Type': 'Public Elementary School',
#   'School Name': 'Falling Creek Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '754 Students',
#   'Phone': '(804) 743-3630'},
#  {'Name': "St. John's Wood",
#   'Apartment_link': 'https://www.apartments.com/st-johns-wood-richmond-va/ch5vx3e/',
#   'Address': '901 Saint Johns Wood Dr, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '678-685-7725',
#   'price_range': '$810 - 1,150',
#   'rating': 3.6,
#   'Type': 'Public Elementary School',
#   'School Name': 'Elizabeth D. Redd Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '475 Students',
#   'Phone': '(804) 780-5061'},
#  {'Name': 'James River at Stony Point',
#   'Apartment_link': 'https://www.apartments.com/james-river-at-stony-point-richmond-va/dhx5kcl/',
#   'Address': '9101 Stony Point Pky, Richmond, VA 23235',
#   'Zipcode': '23235',
#   'phone_number': '844-787-5835',
#   'price_range': '$1,289 - 1,909',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'J.B. Fisher Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '373 Students',
#   'Phone': '(804) 327-5612'},
#  {'Name': 'The Edison Apartments',
#   'Apartment_link': 'https://www.apartments.com/the-edison-apartments-richmond-va/ck48fbe/',
#   'Address': '700 E Franklin St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '804-977-4127',
#   'price_range': '$929 - 1,950',
#   'rating': 4.7,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': '',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'The Village at Westlake',
#   'Apartment_link': 'https://www.apartments.com/the-village-at-westlake-richmond-va/czfym0e/',
#   'Address': '1500 German School Rd, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '844-872-7830',
#   'price_range': '$999 - 1,429',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Southampton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '443 Students',
#   'Phone': '(804) 320-2434'},
#  {'Name': 'Canopy at Ginter Park',
#   'Apartment_link': 'https://www.apartments.com/canopy-at-ginter-park-richmond-va/7csd2rz/',
#   'Address': '3200 Brook Rd, Richmond, VA 23227',
#   'Zipcode': '23227',
#   'phone_number': '855-337-2740',
#   'price_range': '$1,265 - 2,265',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Linwood Holton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '598 Students',
#   'Phone': '(804) 228-5310'},
#  {'Name': 'Monroe Park Towers',
#   'Apartment_link': 'https://www.apartments.com/monroe-park-towers-richmond-va/fznwpyt/',
#   'Address': '520 W Franklin St, Richmond, VA 23220',
#   'Zipcode': '23220',
#   'phone_number': '844-289-9113',
#   'price_range': '$844 - 1,974',
#   'rating': 3.8,
#   'Type': 'Public Elementary School',
#   'School Name': 'William Fox Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '546 Students',
#   'Phone': '(804) 780-6259'},
#  {'Name': 'Park Plaza at Belvidere',
#   'Apartment_link': 'https://www.apartments.com/park-plaza-at-belvidere-richmond-va/747glzz/',
#   'Address': '515 W Franklin St, Richmond, VA 23220',
#   'Zipcode': '23220',
#   'phone_number': '844-253-7804',
#   'price_range': '$1,602 - 2,250',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'George W. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '474 Students',
#   'Phone': '(804) 780-6247'},
#  {'Name': 'North Arch Village',
#   'Apartment_link': 'https://www.apartments.com/north-arch-village-richmond-va/tx0vh1b/',
#   'Address': '9111 N Arch Village Ct, Richmond, VA 23236',
#   'Zipcode': '23236',
#   'phone_number': '844-681-3973',
#   'price_range': '$900 - 1,200',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Reams Road Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '553 Students',
#   'Phone': '(804) 674-1370'},
#  {'Name': 'Ashton Square Apartments',
#   'Apartment_link': 'https://www.apartments.com/ashton-square-apartments-richmond-va/w30tm4j/',
#   'Address': '603-A Westover Hills Blvd, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '844-280-3539',
#   'price_range': '$610 - 964',
#   'rating': 3.7,
#   'Type': 'Public Elementary School',
#   'School Name': 'Westover Hills Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '434 Students',
#   'Phone': '(804) 780-5002'},
#  {'Name': 'Shockoe Valley View Apartments',
#   'Apartment_link': 'https://www.apartments.com/shockoe-valley-view-apartments-richmond-va/sgp51d4/',
#   'Address': '1904 Cedar St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-461-1839',
#   'price_range': '$939 - 1,319',
#   'rating': 4.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'The Villas of Oakwood',
#   'Apartment_link': 'https://www.apartments.com/the-villas-of-oakwood-richmond-va/d7h3rhh/',
#   'Address': '3508 E Richmond Rd, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-799-7991',
#   'price_range': '$740 - 925',
#   'rating': 3.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Chimborazo Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '425 Students',
#   'Phone': '(804) 780-8392'},
#  {'Name': 'College Park Apartments',
#   'Apartment_link': 'https://www.apartments.com/college-park-apartments-richmond-va/ce3m6me/',
#   'Address': '1603 Roane St, Richmond, VA 23222',
#   'Zipcode': '23222',
#   'phone_number': '844-846-5806',
#   'price_range': '$785 - 1,150',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'George W. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '474 Students',
#   'Phone': '(804) 780-6247'},
#  {'Name': 'Reflections of West Creek',
#   'Apartment_link': 'https://www.apartments.com/reflections-of-west-creek-richmond-va/pd8cl9v/',
#   'Address': '4400 Breezy Bay Cir, Richmond, VA 23233',
#   'Zipcode': '23233',
#   'phone_number': '804-708-3902',
#   'price_range': '$1,499',
#   'rating': 4.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Colonial Trail Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '621 Students',
#   'Phone': '(804) 364-0055'},
#  {'Name': 'The Locks Tower',
#   'Apartment_link': 'https://www.apartments.com/the-locks-tower-richmond-va/c58v4yf/',
#   'Address': '1001 E Byrd St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '804-205-1868',
#   'price_range': '$1,124 - 5,650',
#   'rating': None,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': 'Not Listed',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Somerset Glen',
#   'Apartment_link': 'https://www.apartments.com/somerset-glen-richmond-va/ge2g3mz/',
#   'Address': '406 Westover Hills Blvd, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '804-767-3547',
#   'price_range': '$720 - 890',
#   'rating': 2.7,
#   'Type': 'Public Elementary School',
#   'School Name': 'Westover Hills Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '434 Students',
#   'Phone': '(804) 780-5002'},
#  {'Name': 'Colonial Apartments',
#   'Apartment_link': 'https://www.apartments.com/colonial-apartments-richmond-va/4crt54h/',
#   'Address': '5501 Pony Farm Dr, Richmond, VA 23227',
#   'Zipcode': '23227',
#   'phone_number': '804-977-3729',
#   'price_range': '$720 - 1,140',
#   'rating': 3.8,
#   'Type': 'Public Elementary School',
#   'School Name': 'Laburnum Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '627 Students',
#   'Phone': '(804) 228-2720'},
#  {'Name': 'Hunters Ridge',
#   'Apartment_link': 'https://www.apartments.com/hunters-ridge-richmond-va/ytp824r/',
#   'Address': '2400 Milhaven Dr, Richmond, VA 23238',
#   'Zipcode': '23238',
#   'phone_number': '804-419-5955',
#   'price_range': '$1,030 - 1,195',
#   'rating': 3.5,
#   'Type': 'Public Elementary School',
#   'School Name': 'Ruby F. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '550 Students',
#   'Phone': '(804) 750-2640'},
#  {'Name': 'American Tobacco Center',
#   'Apartment_link': 'https://www.apartments.com/american-tobacco-center-richmond-va/gvf4h3y/',
#   'Address': '119-121 N 20th St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-268-9284',
#   'price_range': '$931 - 2,354',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Cedar Broad',
#   'Apartment_link': 'https://www.apartments.com/cedar-broad-richmond-va/gem8m5z/',
#   'Address': '1820 E Broad St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-265-0979',
#   'price_range': '$860 - 1,785',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Terraces at Manchester',
#   'Apartment_link': 'https://www.apartments.com/terraces-at-manchester-richmond-va/ngsj4zm/',
#   'Address': '800 Semmes Ave, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '844-615-8171',
#   'price_range': '$1,050 - 3,500',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': 'Deco at CNB',
#   'Apartment_link': 'https://www.apartments.com/deco-at-cnb-richmond-va/2sczzjb/',
#   'Address': '219 E Broad St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '844-492-1883',
#   'price_range': '$987 - 2,342',
#   'rating': None,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': 'Not Listed',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Retreat at West Creek',
#   'Apartment_link': 'https://www.apartments.com/retreat-at-west-creek-richmond-va/ywbrymr/',
#   'Address': '1000 Wilkes Ridge Pl, Richmond, VA 23233',
#   'Zipcode': '23233',
#   'phone_number': '855-881-2183',
#   'price_range': '$1,313 - 3,023',
#   'rating': 4.7,
#   'Type': 'Public Elementary School',
#   'School Name': 'Randolph Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '493 Students',
#   'Phone': '(804) 556-5385'},
#  {'Name': 'Element at Stonebridge',
#   'Apartment_link': 'https://www.apartments.com/element-at-stonebridge-richmond-va/byw4yj9/',
#   'Address': '301 Karl Linn Dr, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '844-269-0814',
#   'price_range': '$1,049 - 1,479',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'A M Davis Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '689 Students',
#   'Phone': '(804) 674-1310'},
#  {'Name': 'Bloom Apartments',
#   'Apartment_link': 'https://www.apartments.com/bloom-apartments-richmond-va/658ydcs/',
#   'Address': '3211 Chamberlayne Ave, Richmond, VA 23227',
#   'Zipcode': '23227',
#   'phone_number': '844-262-0130',
#   'price_range': '$619 - 899',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Linwood Holton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '598 Students',
#   'Phone': '(804) 228-5310'},
#  {'Name': 'Overview',
#   'Apartment_link': 'https://www.apartments.com/overview-richmond-va/fsc82pv/',
#   'Address': '1817 E Main St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '888-345-1619',
#   'price_range': '$1,322 - 3,382',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'The Edge',
#   'Apartment_link': 'https://www.apartments.com/the-edge-richmond-va/88xevw0/',
#   'Address': '1914 E Franklin St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '804-316-9084',
#   'price_range': '$1,075 - 1,835',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Symbol Apartments',
#   'Apartment_link': 'https://www.apartments.com/symbol-apartments-richmond-va/vqn9pcg/',
#   'Address': '1814 Highpoint Ave, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '888-830-4568',
#   'price_range': '$1,406 - 2,492',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': '2000 West Creek',
#   'Apartment_link': 'https://www.apartments.com/2000-west-creek-richmond-va/t869k6b/',
#   'Address': '2000 Broad Branch Cir, Richmond, VA 23238',
#   'Zipcode': '23238',
#   'phone_number': '888-788-7915',
#   'price_range': '$1,215 - 3,380',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Randolph Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '493 Students',
#   'Phone': '(804) 556-5385'},
#  {'Name': "River's Edge at Manchester",
#   'Apartment_link': 'https://www.apartments.com/rivers-edge-at-manchester-richmond-va/fxj7qrr/',
#   'Address': '505 Porter St, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '804-396-6534',
#   'price_range': '$1,199 - 4,364',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': "Scott's View",
#   'Apartment_link': 'https://www.apartments.com/scotts-view-richmond-va/w0vb1rk/',
#   'Address': '1400 Roseneath Rd, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '804-208-0441',
#   'price_range': '$1,170 - 1,835',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'Hardwicke House',
#   'Apartment_link': 'https://www.apartments.com/hardwicke-house-richmond-va/8q5w293/',
#   'Address': '3212 Cutshaw Ave, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '804-417-7047',
#   'price_range': 'Call for Rent',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'Fording Flats',
#   'Apartment_link': 'https://www.apartments.com/fording-flats-richmond-va/bgqwreb/',
#   'Address': '2213 E Franklin St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '804-414-8482',
#   'price_range': '$1,669',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Flats at 25th',
#   'Apartment_link': 'https://www.apartments.com/flats-at-25th-richmond-va/k9rjrl8/',
#   'Address': '2400 Fairmount Ave, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '202-851-6690',
#   'price_range': '$850 - 1,250',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'George Mason Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '452 Students',
#   'Phone': '(804) 780-4401'},
#  {'Name': 'Millspring Commons',
#   'Apartment_link': 'https://www.apartments.com/millspring-commons-richmond-va/5xmj1sn/',
#   'Address': '9318 Tarheel Ter, Richmond, VA 23228',
#   'Zipcode': '23228',
#   'phone_number': '804-496-7122',
#   'price_range': '$1,129 - 1,639',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Dumbarton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '632 Students',
#   'Phone': '(804) 756-3030'},
#  {'Name': 'Stony Point',
#   'Apartment_link': 'https://www.apartments.com/stony-point-richmond-va/gzkrhmy/',
#   'Address': '3012 Stony Lake Dr, Richmond, VA 23235',
#   'Zipcode': '23235',
#   'phone_number': '844-365-3117',
#   'price_range': '$1,164 - 1,396',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'J.B. Fisher Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '373 Students',
#   'Phone': '(804) 327-5612'},
#  {'Name': 'Harbor Village Apartments',
#   'Apartment_link': 'https://www.apartments.com/harbor-village-apartments-richmond-va/g5rd91z/',
#   'Address': '2370 Harpoon Ct, Richmond, VA 23294',
#   'Zipcode': '23294',
#   'phone_number': '866-249-6227',
#   'price_range': '$1,195 - 2,670',
#   'rating': 4.1,
#   'Type': 'Public Elementary School',
#   'School Name': 'Skipwith Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '542 Students',
#   'Phone': '(804) 527-4650'},
#  {'Name': 'Park West End',
#   'Apartment_link': 'https://www.apartments.com/park-west-end-richmond-va/shh0l77/',
#   'Address': '5300 Glenside Dr, Richmond, VA 23228',
#   'Zipcode': '23228',
#   'phone_number': '866-403-9073',
#   'price_range': '$840 - 2,045',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Johnson Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '541 Students',
#   'Phone': '(804) 673-3735'},
#  {'Name': 'East 51 At Rocketts Landing',
#   'Apartment_link': 'https://www.apartments.com/east-51-at-rocketts-landing-richmond-va/mdq1dkj/',
#   'Address': '5101-5151 Old Main St, Richmond, VA 23231',
#   'Zipcode': '23231',
#   'phone_number': '804-977-3657',
#   'price_range': '$1,138 - 2,495',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Chimborazo Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '425 Students',
#   'Phone': '(804) 780-8392'},
#  {'Name': 'Penstock Quarter Apartments',
#   'Apartment_link': 'https://www.apartments.com/penstock-quarter-apartments-richmond-va/zj5142y/',
#   'Address': '5001 Libbie Mill East Blvd, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '804-419-7621',
#   'price_range': '$1,156 - 2,684',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Johnson Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '541 Students',
#   'Phone': '(804) 673-3735'},
#  {'Name': 'Miller and Rhoads Residences',
#   'Apartment_link': 'https://www.apartments.com/miller-and-rhoads-residences-richmond-va/9qrg4l4/',
#   'Address': '230 N 6th St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '804-767-8907',
#   'price_range': '$1,575 - 2,750',
#   'rating': 5.0,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': 'Not Listed',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Vida East Apartments',
#   'Apartment_link': 'https://www.apartments.com/vida-east-apartments-richmond-va/r4e9343/',
#   'Address': '1903 E Marshall St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-279-4930',
#   'price_range': '$899 - 1,729',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'Link Apartments Manchester',
#   'Apartment_link': 'https://www.apartments.com/link-apartments-manchester-richmond-va/dvmkr2k/',
#   'Address': '901 McDonough St, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '888-497-8838',
#   'price_range': '$1,058 - 2,627',
#   'rating': 4.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': 'The Preserve at Scotts Addition',
#   'Apartment_link': 'https://www.apartments.com/the-preserve-at-scotts-addition-richmond-va/s9bwcn6/',
#   'Address': '1310 Roseneath Rd, Richmond, VA 23230',
#   'Zipcode': '23230',
#   'phone_number': '844-880-4283',
#   'price_range': '$1,112 - 2,023',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'The Locks Apartments*',
#   'Apartment_link': 'https://www.apartments.com/the-locks-apartments-richmond-va/58ek15p/',
#   'Address': '311 S 11th St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '866-954-9917',
#   'price_range': '$1,297 - 3,286',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'George W. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '474 Students',
#   'Phone': '(804) 780-6247'},
#  {'Name': 'Hickory Creek Apartments',
#   'Apartment_link': 'https://www.apartments.com/hickory-creek-apartments-richmond-va/pzevkxv/',
#   'Address': '2344 Hickory Creek Dr, Richmond, VA 23294',
#   'Zipcode': '23294',
#   'phone_number': '844-832-3044',
#   'price_range': '$990 - 1,487',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Skipwith Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '542 Students',
#   'Phone': '(804) 527-4650'},
#  {'Name': 'Copper Mill Apartments',
#   'Apartment_link': 'https://www.apartments.com/copper-mill-apartments-richmond-va/8pc5ff3/',
#   'Address': '3400 Copper Mill Trace, Richmond, VA 23294',
#   'Zipcode': '23294',
#   'phone_number': '844-293-8479',
#   'price_range': '$1,179 - 1,378',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Davis Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '552 Students',
#   'Phone': '(804) 527-4620'},
#  {'Name': 'South Bank',
#   'Apartment_link': 'https://www.apartments.com/south-bank-richmond-va/rg5rq81/',
#   'Address': '307 Stockton St, Richmond, VA 23224',
#   'Zipcode': '23224',
#   'phone_number': '844-215-3652',
#   'price_range': '$987 - 1,716',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Blackwell Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '680 Students',
#   'Phone': '(804) 780-5078'},
#  {'Name': 'The Wilton Apartments',
#   'Apartment_link': 'https://www.apartments.com/the-wilton-apartments-richmond-va/fh5jr3t/',
#   'Address': '9101 Patterson Ave, Richmond, VA 23229',
#   'Zipcode': '23229',
#   'phone_number': '844-632-5102',
#   'price_range': '$893 - 1,295',
#   'rating': 3.8,
#   'Type': 'Public Elementary School',
#   'School Name': 'Maybeury Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '676 Students',
#   'Phone': '(804) 750-2650'},
#  {'Name': 'The Gallery',
#   'Apartment_link': 'https://www.apartments.com/the-gallery-richmond-va/3jkzexd/',
#   'Address': '308 N Nansemond St, Richmond, VA 23221',
#   'Zipcode': '23221',
#   'phone_number': '844-808-5839',
#   'price_range': '$1,334',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'John B. Cary Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '265 Students',
#   'Phone': '(804) 780-6252'},
#  {'Name': 'Avia',
#   'Apartment_link': 'https://www.apartments.com/avia-richmond-va/y96k2tv/',
#   'Address': '5200 Avia Way, Richmond, VA 23233',
#   'Zipcode': '23233',
#   'phone_number': '804-442-6424',
#   'price_range': '$1,445 - 2,809',
#   'rating': 5.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Kaechele Elementary',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '440 Students',
#   'Phone': '(804) 364-0055'},
#  {'Name': 'Amber Ridge Apartments',
#   'Apartment_link': 'https://www.apartments.com/amber-ridge-apartments-richmond-va/42qz4cj/',
#   'Address': '5601 Goldthread Ln, Richmond, VA 23228',
#   'Zipcode': '23228',
#   'phone_number': '804-977-3772',
#   'price_range': '$801 - 1,462',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Dumbarton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '632 Students',
#   'Phone': '(804) 756-3030'},
#  {'Name': 'Residences at the John Marshall',
#   'Apartment_link': 'https://www.apartments.com/residences-at-the-john-marshall-richmond-va/5r63gkm/',
#   'Address': '101 N 5th St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '877-414-3691',
#   'price_range': '$1,100 - 2,724',
#   'rating': 5.0,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': 'Not Listed',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'Meadowbrook Apartments',
#   'Apartment_link': 'https://www.apartments.com/meadowbrook-apartments-richmond-va/qgtwtsy/',
#   'Address': '5314 Whetstone Rd, Richmond, VA 23234',
#   'Zipcode': '23234',
#   'phone_number': '877-661-7403',
#   'price_range': '$870 - 1,510',
#   'rating': 3.2,
#   'Type': 'Public Elementary School',
#   'School Name': 'Falling Creek Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '754 Students',
#   'Phone': '(804) 743-3630'},
#  {'Name': "St. John's Wood",
#   'Apartment_link': 'https://www.apartments.com/st-johns-wood-richmond-va/ch5vx3e/',
#   'Address': '901 Saint Johns Wood Dr, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '678-685-7725',
#   'price_range': '$810 - 1,150',
#   'rating': 3.6,
#   'Type': 'Public Elementary School',
#   'School Name': 'Elizabeth D. Redd Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '475 Students',
#   'Phone': '(804) 780-5061'},
#  {'Name': 'James River at Stony Point',
#   'Apartment_link': 'https://www.apartments.com/james-river-at-stony-point-richmond-va/dhx5kcl/',
#   'Address': '9101 Stony Point Pky, Richmond, VA 23235',
#   'Zipcode': '23235',
#   'phone_number': '844-787-5835',
#   'price_range': '$1,289 - 1,909',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'J.B. Fisher Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '373 Students',
#   'Phone': '(804) 327-5612'},
#  {'Name': 'The Edison Apartments',
#   'Apartment_link': 'https://www.apartments.com/the-edison-apartments-richmond-va/ck48fbe/',
#   'Address': '700 E Franklin St, Richmond, VA 23219',
#   'Zipcode': '23219',
#   'phone_number': '804-977-4127',
#   'price_range': '$929 - 1,950',
#   'rating': 4.7,
#   'Type': 'Public Elementary, Middle & High School',
#   'School Name': 'Richmond Hospital Ep.',
#   'Grade Levels': 'Grades PK-12',
#   'Student Count': 'Not Listed',
#   'Phone': '(804) 828-0426'},
#  {'Name': 'The Village at Westlake',
#   'Apartment_link': 'https://www.apartments.com/the-village-at-westlake-richmond-va/czfym0e/',
#   'Address': '1500 German School Rd, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '844-872-7830',
#   'price_range': '$999 - 1,429',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Southampton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '443 Students',
#   'Phone': '(804) 320-2434'},
#  {'Name': 'Canopy at Ginter Park',
#   'Apartment_link': 'https://www.apartments.com/canopy-at-ginter-park-richmond-va/7csd2rz/',
#   'Address': '3200 Brook Rd, Richmond, VA 23227',
#   'Zipcode': '23227',
#   'phone_number': '855-337-2740',
#   'price_range': '$1,265 - 2,265',
#   'rating': None,
#   'Type': 'Public Elementary School',
#   'School Name': 'Linwood Holton Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '598 Students',
#   'Phone': '(804) 228-5310'},
#  {'Name': 'Monroe Park Towers',
#   'Apartment_link': 'https://www.apartments.com/monroe-park-towers-richmond-va/fznwpyt/',
#   'Address': '520 W Franklin St, Richmond, VA 23220',
#   'Zipcode': '23220',
#   'phone_number': '844-289-9113',
#   'price_range': '$844 - 1,974',
#   'rating': 3.8,
#   'Type': 'Public Elementary School',
#   'School Name': 'William Fox Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '546 Students',
#   'Phone': '(804) 780-6259'},
#  {'Name': 'Park Plaza at Belvidere',
#   'Apartment_link': 'https://www.apartments.com/park-plaza-at-belvidere-richmond-va/747glzz/',
#   'Address': '515 W Franklin St, Richmond, VA 23220',
#   'Zipcode': '23220',
#   'phone_number': '844-253-7804',
#   'price_range': '$1,602 - 2,250',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'George W. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '474 Students',
#   'Phone': '(804) 780-6247'},
#  {'Name': 'North Arch Village',
#   'Apartment_link': 'https://www.apartments.com/north-arch-village-richmond-va/tx0vh1b/',
#   'Address': '9111 N Arch Village Ct, Richmond, VA 23236',
#   'Zipcode': '23236',
#   'phone_number': '844-681-3973',
#   'price_range': '$900 - 1,200',
#   'rating': 4.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Reams Road Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '553 Students',
#   'Phone': '(804) 674-1370'},
#  {'Name': 'Ashton Square Apartments',
#   'Apartment_link': 'https://www.apartments.com/ashton-square-apartments-richmond-va/w30tm4j/',
#   'Address': '603-A Westover Hills Blvd, Richmond, VA 23225',
#   'Zipcode': '23225',
#   'phone_number': '844-280-3539',
#   'price_range': '$610 - 964',
#   'rating': 3.7,
#   'Type': 'Public Elementary School',
#   'School Name': 'Westover Hills Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '434 Students',
#   'Phone': '(804) 780-5002'},
#  {'Name': 'Shockoe Valley View Apartments',
#   'Apartment_link': 'https://www.apartments.com/shockoe-valley-view-apartments-richmond-va/sgp51d4/',
#   'Address': '1904 Cedar St, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-461-1839',
#   'price_range': '$939 - 1,319',
#   'rating': 4.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Bellevue Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '306 Students',
#   'Phone': '(804) 780-4417'},
#  {'Name': 'The Villas of Oakwood',
#   'Apartment_link': 'https://www.apartments.com/the-villas-of-oakwood-richmond-va/d7h3rhh/',
#   'Address': '3508 E Richmond Rd, Richmond, VA 23223',
#   'Zipcode': '23223',
#   'phone_number': '844-799-7991',
#   'price_range': '$740 - 925',
#   'rating': 3.0,
#   'Type': 'Public Elementary School',
#   'School Name': 'Chimborazo Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '425 Students',
#   'Phone': '(804) 780-8392'},
#  {'Name': 'College Park Apartments',
#   'Apartment_link': 'https://www.apartments.com/college-park-apartments-richmond-va/ce3m6me/',
#   'Address': '1603 Roane St, Richmond, VA 23222',
#   'Zipcode': '23222',
#   'phone_number': '844-846-5806',
#   'price_range': '$785 - 1,150',
#   'rating': 3.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'George W. Carver Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '474 Students',
#   'Phone': '(804) 780-6247'},
#  {'Name': 'Reflections of West Creek',
#   'Apartment_link': 'https://www.apartments.com/reflections-of-west-creek-richmond-va/pd8cl9v/',
#   'Address': '4400 Breezy Bay Cir, Richmond, VA 23233',
#   'Zipcode': '23233',
#   'phone_number': '804-708-3902',
#   'price_range': '$1,499',
#   'rating': 4.9,
#   'Type': 'Public Elementary School',
#   'School Name': 'Colonial Trail Elementary School',
#   'Grade Levels': 'Grades PK-5',
#   'Student Count': '621 Students',
#   'Phone': '(804) 364-0055'}]

# %%
for i in apartment_info:
    print(i['rating'])
# Out:
# None
# 2.7
# 3.8
# 3.5
# 3.9
# 5.0
# None
# None
# 4.7
# None
# 4.0
# None
# None
# None
# 5.0
# 5.0
# None
# None
# None
# None
# 4.0
# 3.9
# 4.1
# 4.0
# None
# None
# 5.0
# 5.0
# 4.9
# 3.9
# 5.0
# 4.0
# 4.0
# 5.0
# 3.8
# None
# 5.0
# 4.0
# 5.0
# 3.2
# 3.6
# 4.0
# 4.7
# None
# None
# 3.8
# 4.0
# 4.0
# 3.7
# 4.9
# 3.0
# 3.9
# 4.9
# None
# 2.7
# 3.8
# 3.5
# 3.9
# 5.0
# None
# None
# 4.7
# None
# 4.0
# None
# None
# None
# 5.0
# 5.0
# None
# None
# None
# None
# 4.0
# 3.9
# 4.1
# 4.0
# None
# None
# 5.0
# 5.0
# 4.9
# 3.9
# 5.0
# 4.0
# 4.0
# 5.0
# 3.8
# None
# 5.0
# 4.0
# 5.0
# 3.2
# 3.6
# 4.0
# 4.7
# None
# None
# 3.8
# 4.0
# 4.0
# 3.7
# 4.9
# 3.0
# 3.9
# 4.9
